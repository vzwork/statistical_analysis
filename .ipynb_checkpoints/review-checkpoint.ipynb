# %% [markdown]
# <font color='DarkBlue' size=+2><b>Комментарий ревьюера</b></font><br>
# <font color='DarkBlue'>Привет, Владислав! <br>Меня зовут Олег Мазуренко, и я буду проверять этот проект. Спасибо за проделанную работу! <br>Ко мне можно обращаться на «ты». Как мне обращаться, напиши.</font><br>
# <font color='DarkBlue'>Я буду использовать различные цвета, чтобы было удобнее воспринимать мои комментарии:</font><br>
# <font color='DarkBlue'>Синий текст &mdash; просто текст комментария.</font><br>
# <font color='DarkGreen'>👌 Зеленый текст &mdash; все отлично.</font><br>
# <font color='DarkMagenta'>👉 Фиолетовый текст &mdash; сделано все правильно, однако есть рекомендации, на что стоит обратить внимание. Реализованные рекомендации позволят нам наработать опыт решения задачи разными способами или посмотреть на задачу под иным углом.</font><br>
# <font color='Red'>🛠 Красный текст &mdash; есть недочеты, они иногда бывают. </font><br><font color='DarkBlue'>Любая ошибка это возможность посмотреть на задачу с другой стороны и освоить новые знания, по этому не надо расстраиваться, если они есть.</font><br>
# <font color='DarkBlue'>Пожалуйста, не удаляй мои комментарии в случае возврата работы, так будет проще разобраться, какие были недочеты и сразу увидеть исправленное. <br>
# Ответы на мои комментарии лучше тоже помечать.
# Например: </font><font color='Blue'><b>Комментарий студента</b></font><br>
# <font color='DarkBlue'><b>Теперь посмотрим, что у нас получилось!</b></font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Любой проект, как учебный, так и реальный, начинается с его краткого описания, содержащего цель исследования, описание данных, особенности их преобразования (в нашем случае, особенности округления длительности звонков и интренет-трафика).</font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Почему не исправили эту ошибку?</font>

# %% [markdown]
# <p style='background-color:green'>я использовал вс код, извинения за формат, в вс можно удобно свернуть все клетки с помощю '#'</p>

# %% [markdown]
# # План

# %% [markdown]
# 1. Откройте файл с данными и изучите общую информацию
# 2. Подготовьте данные
#    - тип данных
#    - ошибки
#    - новые данные
#      - количество звонков
#      - количество минут
#      - количество сообщений
#      - интернет (gb)
#      - веручка
# 3. Проанализируйте данные
#    - фрейм для каждого тарифа
#    - посчитайте среднее количество, дисперсию и стандартное отклонение
#    - постройте гистограммы. Опишите распределения
# 4. Проверьте гипотезы
#    - средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются
#    - средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов
# 5. Напишите общий вывод

# %% [markdown]
# # необходимые библиотеки

# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
import os
import random

# %% [markdown]
# # Откройте файл с данными и изучите общую информацию

# %%
# Комментарий ревьюера
#df_users = pd.read_csv('./datasets/users.csv')
#df_tariffs = pd.read_csv('./datasets/tariffs.csv')
#df_messages = pd.read_csv('./datasets/messages.csv')
#df_internet = pd.read_csv('./datasets/internet.csv')
#df_calls = pd.read_csv('./datasets/calls.csv')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Ну вот, нам не повезло. Я исправлю, но в следующих проектах это надо учитывать, так как после такой ошибки проверка проекта прекращается и он отправляется на доработку. 😢</font><br>
# <font color='DarkMagenta'>👉 Для того что бы не получать ошибки при загрузке файла, то локально, то с сервера, можно воспользоваться следующим кодом:</font><br>
# `import os
# pth1 = '/folder_1/data.csv'
# pth2 = '/folder_2/data.csv'
# if os.path.exists(pth1):
#     df = pd.read_csv(pth1)
# elif os.path.exists(pth2):
#     df = pd.read_csv(pth2)
# else:<br>
#     print("Проверьте правильность пути к датасету")`
# ![image.png](attachment:image.png)

# %%
# Комментарий ревьюера
# df_users = pd.read_csv('/datasets/users.csv')
# df_tariffs = pd.read_csv('/datasets/tariffs.csv')
# df_messages = pd.read_csv('/datasets/messages.csv')
# df_internet = pd.read_csv('/datasets/internet.csv')
# df_calls = pd.read_csv('/datasets/calls.csv')

# %%
local_path_df_users = './datasets/users.csv'
local_path_df_tariffs = './datasets/tariffs.csv'
local_path_df_messages = './datasets/messages.csv'
local_path_df_internet = './datasets/internet.csv'
local_path_df_calls = './datasets/calls.csv'
web_path_df_users = '/datasets/users.csv'
web_path_df_tariffs = '/datasets/tariffs.csv'
web_path_df_messages = '/datasets/messages.csv'
web_path_df_internet = '/datasets/internet.csv'
web_path_df_calls = '/datasets/calls.csv'

# %%
if os.path.exists(local_path_df_users):
  df_users = pd.read_csv(local_path_df_users)
elif os.path.exists(web_path_df_users):
  df_users = pd.read_csv(web_path_df_users)
if os.path.exists(local_path_df_tariffs):
  df_tariffs = pd.read_csv(local_path_df_tariffs)
elif os.path.exists(web_path_df_tariffs):
  df_tariffs = pd.read_csv(web_path_df_tariffs)
if os.path.exists(local_path_df_messages):
  df_messages = pd.read_csv(local_path_df_messages)
elif os.path.exists(web_path_df_messages):
  df_messages = pd.read_csv(web_path_df_messages)
if os.path.exists(local_path_df_internet):
  df_internet = pd.read_csv(local_path_df_internet)
elif os.path.exists(web_path_df_internet):
  df_internet = pd.read_csv(web_path_df_internet)
if os.path.exists(local_path_df_calls):
  df_calls = pd.read_csv(local_path_df_calls)
elif os.path.exists(web_path_df_calls):
  df_calls = pd.read_csv(web_path_df_calls)

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB

# %%
df_tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %%
df_messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB

# %%
df_internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB

# %%
df_calls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB

# %% [markdown]
# # Подготовьте данные

# %% [markdown]
# ## Приведите данные к нужным типам

# %% [markdown]
# ### fix data type: users

# %%
df_users.info()
df_users.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     object
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    object
#  7   tariff      500 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 31.4+ KB
#    user_id  age churn_date         city first_name  last_name    reg_date  \
# 0     1000   52        NaN    Краснодар     Рафаил  Верещагин  2018-05-25
# 1     1001   41        NaN       Москва       Иван       Ежов  2018-11-01
# 2     1002   59        NaN  Стерлитамак    Евгений  Абрамович  2018-06-17
# 3     1003   23        NaN       Москва      Белла   Белякова  2018-08-17
# ...

# %% [markdown]
# columns to fix:
# - reg_date:     object -> datetime
# - churn_date:  object -> datetime

# %%
df_users['reg_date'] = pd.to_datetime(df_users['reg_date'], errors='coerce')

# %%
df_users['reg_date'].head()
# Out:
# 0   2018-05-25
# 1   2018-11-01
# 2   2018-06-17
# 3   2018-08-17
# 4   2018-05-14
# Name: reg_date, dtype: datetime64[ns]

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='Red'>🛠 Ну вот, у нас опять ошибка кода. Вынужден прервать проверку. 😢</font>
# ![image.png](attachment:image.png)

# %%
df_users['churn_date'] = pd.to_datetime(df_users['churn_date'], errors='coerce')

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, перевели даты в нужный формат. 👍</font>

# %%
df_users['churn_date'].head()
# Out:
# 0   NaT
# 1   NaT
# 2   NaT
# 3   NaT
# 4   NaT
# Name: churn_date, dtype: datetime64[ns]

# %% [markdown]
# ### fix data type: messages

# %%
df_messages.info()
df_messages.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  object
#  2   user_id       123036 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 2.8+ MB
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %% [markdown]
# columns to fix:
# - message_date: object -> datetime

# %%
df_messages['message_date'] = pd.to_datetime(df_messages['message_date'], errors='coerce')

# %%
df_messages.info()
df_messages.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  datetime64[ns]
#  2   user_id       123036 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %% [markdown]
# ### fix data type: internet

# %%
df_internet.info()
df_internet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    149396 non-null  int64
#  1   id            149396 non-null  object
#  2   mb_used       149396 non-null  float64
#  3   session_date  149396 non-null  object
#  4   user_id       149396 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.7+ MB
#    Unnamed: 0      id  mb_used session_date  user_id
# 0           0  1000_0   112.95   2018-11-25     1000
# 1           1  1000_1  1052.81   2018-09-07     1000
# 2           2  1000_2  1197.26   2018-06-25     1000
# 3           3  1000_3   550.27   2018-08-22     1000
# 4           4  1000_4   302.56   2018-09-24     1000

# %%
df_internet.tail()
# Out:
#         Unnamed: 0        id  mb_used session_date  user_id
# 149391      149391  1499_152   318.90   2018-10-03     1499
# 149392      149392  1499_153   490.13   2018-12-14     1499
# 149393      149393  1499_154     0.00   2018-10-27     1499
# 149394      149394  1499_155  1246.32   2018-11-26     1499
# 149395      149395  1499_156   544.37   2018-10-26     1499

# %% [markdown]
# columns to fix:
# - first column: drop it
# - session_date: object -> datetime

# %%
df_internet = df_internet.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, что удалили колонку Unnamed: 0, в принципе, от нее можно было избавиться на этапе загрузки датасета вот таким кодом: <br>`pd.read_csv(..., index_col=False)`. 😉</font>

# %%
df_internet['session_date'] = pd.to_datetime(df_internet['session_date'], errors='coerce')

# %%
df_internet.info()
df_internet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            149396 non-null  object
#  1   mb_used       149396 non-null  float64
#  2   session_date  149396 non-null  datetime64[ns]
#  3   user_id       149396 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 4.6+ MB
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000

# %% [markdown]
# ### fix data type: calls

# %%
df_calls.info()
df_calls.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  object
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.2+ MB
#        id   call_date  duration  user_id
# 0  1000_0  2018-07-25      0.00     1000
# 1  1000_1  2018-08-17      0.00     1000
# 2  1000_2  2018-06-11      2.85     1000
# 3  1000_3  2018-09-21     13.80     1000
# 4  1000_4  2018-12-15      5.18     1000

# %% [markdown]
# columns to fix:
# - call_date: object -> datetime

# %%
df_calls['call_date'] = pd.to_datetime(df_calls['call_date'], errors='coerce')

# %%
df_calls.info()
df_calls.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  datetime64[ns]
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 6.2+ MB
#        id  call_date  duration  user_id
# 0  1000_0 2018-07-25      0.00     1000
# 1  1000_1 2018-08-17      0.00     1000
# 2  1000_2 2018-06-11      2.85     1000
# 3  1000_3 2018-09-21     13.80     1000
# 4  1000_4 2018-12-15      5.18     1000

# %% [markdown]
# ## fix errors

# %% [markdown]
# ### fix errors: users

# %%
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     500 non-null    int64
#  1   age         500 non-null    int64
#  2   churn_date  38 non-null     datetime64[ns]
#  3   city        500 non-null    object
#  4   first_name  500 non-null    object
#  5   last_name   500 non-null    object
#  6   reg_date    500 non-null    datetime64[ns]
#  7   tariff      500 non-null    object
# dtypes: datetime64[ns](2), int64(2), object(4)
# memory usage: 31.4+ KB

# %%
df_users['age'].describe()
# Out:
# count    500.00000
# mean      46.58800
# std       16.66763
# min       18.00000
# 25%       32.00000
# 50%       46.00000
# 75%       62.00000
# max       75.00000
# Name: age, dtype: float64

# %%
df_users['reg_date'].describe(datetime_is_numeric=True)
# Out:
# count                              500
# mean     2018-06-30 18:57:35.999999744
# min                2018-01-01 00:00:00
# 25%                2018-04-07 12:00:00
# 50%                2018-07-02 12:00:00
# 75%                2018-09-29 00:00:00
# max                2018-12-31 00:00:00
# Name: reg_date, dtype: object

# %%
df_users['churn_date'].describe(datetime_is_numeric=True)
# Out:
# count                               38
# mean     2018-11-13 00:37:53.684210432
# min                2018-08-17 00:00:00
# 25%                2018-10-14 00:00:00
# 50%                2018-11-24 00:00:00
# 75%                2018-12-15 12:00:00
# max                2018-12-30 00:00:00
# Name: churn_date, dtype: object

# %% [markdown]
# there should be only two types of tariff

# %%
df_users['tariff'].describe()
# Out:
# count       500
# unique        2
# top       smart
# freq        351
# Name: tariff, dtype: object

# %% [markdown]
# everything else looks good

# %% [markdown]
# ### fix errors: tarrifs

# %%
df_tariffs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   messages_included      2 non-null      int64
#  1   mb_per_month_included  2 non-null      int64
#  2   minutes_included       2 non-null      int64
#  3   rub_monthly_fee        2 non-null      int64
#  4   rub_per_gb             2 non-null      int64
#  5   rub_per_message        2 non-null      int64
#  6   rub_per_minute         2 non-null      int64
#  7   tariff_name            2 non-null      object
# dtypes: int64(7), object(1)
# memory usage: 256.0+ bytes

# %%
df_tariffs.head()
# Out:
#    messages_included  mb_per_month_included  minutes_included  \
# 0                 50                  15360               500
# 1               1000                  30720              3000
#
#    rub_monthly_fee  rub_per_gb  rub_per_message  rub_per_minute tariff_name
# 0              550         200                3               3       smart
# 1             1950         150                1               1       ultra

# %% [markdown]
# everything else looks good

# %% [markdown]
# ### fix errors: messages

# %%
df_messages.info()
df_messages.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123036 entries, 0 to 123035
# Data columns (total 3 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            123036 non-null  object
#  1   message_date  123036 non-null  datetime64[ns]
#  2   user_id       123036 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.8+ MB
#        id message_date  user_id
# 0  1000_0   2018-06-27     1000
# 1  1000_1   2018-10-08     1000
# 2  1000_2   2018-08-04     1000
# 3  1000_3   2018-06-16     1000
# 4  1000_4   2018-12-05     1000

# %%
df_messages['message_date'].describe(datetime_is_numeric=True)
# Out:
# count                           123036
# mean     2018-09-04 15:28:42.227640576
# min                2018-01-02 00:00:00
# 25%                2018-07-09 00:00:00
# 50%                2018-09-20 00:00:00
# 75%                2018-11-14 00:00:00
# max                2018-12-31 00:00:00
# Name: message_date, dtype: object

# %% [markdown]
# looks good

# %% [markdown]
# we can check if first four letters of "id" is equal to the "user_id" in the whole database

# %%
def check_id(id, user_id):
  id_int_value = int(id[0:4])
  if (id_int_value == user_id):
    return True
  return False

df_messages['good_id'] = df_messages.apply(lambda row : check_id(row['id'], row['user_id']), axis=1)

# %% [markdown]
# should be 123036 "True" values as rows in this table

# %%
df_messages['good_id'].value_counts()
# Out:
# True    123036
# Name: good_id, dtype: int64

# %%
df_messages = df_messages.drop(['good_id'], axis=1)

# %% [markdown]
# everything else looks good

# %% [markdown]
# ### fix errors: internet

# %%
df_internet.info()
df_internet.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149396 entries, 0 to 149395
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            149396 non-null  object
#  1   mb_used       149396 non-null  float64
#  2   session_date  149396 non-null  datetime64[ns]
#  3   user_id       149396 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 4.6+ MB
#        id  mb_used session_date  user_id
# 0  1000_0   112.95   2018-11-25     1000
# 1  1000_1  1052.81   2018-09-07     1000
# 2  1000_2  1197.26   2018-06-25     1000
# 3  1000_3   550.27   2018-08-22     1000
# 4  1000_4   302.56   2018-09-24     1000

# %%
df_internet['session_date'].describe(datetime_is_numeric=True)
# Out:
# count                           149396
# mean     2018-09-02 12:55:35.221826560
# min                2018-01-01 00:00:00
# 25%                2018-07-05 00:00:00
# 50%                2018-09-17 00:00:00
# 75%                2018-11-14 00:00:00
# max                2018-12-31 00:00:00
# Name: session_date, dtype: object

# %%
df_internet['mb_used'].describe()
# Out:
# count    149396.000000
# mean        370.192426
# std         278.300951
# min           0.000000
# 25%         138.187500
# 50%         348.015000
# 75%         559.552500
# max        1724.830000
# Name: mb_used, dtype: float64

# %%
df_internet['mb_used'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# looks good, no outliers, and max data used just over 1.5 gb (per session)

# %% [markdown]
# everything else looks good

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Было бы правильно сделать анализ аномалий в датасете по интернет-трафику, лучше визуализировать гистограммой. Проанализировать их причину и принять решение по обработке.</font>

# %% [markdown]
# ### fix errors: calls

# %%
df_calls.info()
df_calls.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202607 entries, 0 to 202606
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   id         202607 non-null  object
#  1   call_date  202607 non-null  datetime64[ns]
#  2   duration   202607 non-null  float64
#  3   user_id    202607 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 6.2+ MB
#        id  call_date  duration  user_id
# 0  1000_0 2018-07-25      0.00     1000
# 1  1000_1 2018-08-17      0.00     1000
# 2  1000_2 2018-06-11      2.85     1000
# 3  1000_3 2018-09-21     13.80     1000
# 4  1000_4 2018-12-15      5.18     1000

# %%
df_calls['call_date'].describe(datetime_is_numeric=True)
# Out:
# count                           202607
# mean     2018-09-02 20:01:37.583992832
# min                2018-01-01 00:00:00
# 25%                2018-07-05 00:00:00
# 50%                2018-09-17 00:00:00
# 75%                2018-11-14 00:00:00
# max                2018-12-31 00:00:00
# Name: call_date, dtype: object

# %%
df_calls['duration'].describe()
# Out:
# count    202607.000000
# mean          6.755887
# std           5.843365
# min           0.000000
# 25%           1.300000
# 50%           6.000000
# 75%          10.700000
# max          38.000000
# Name: duration, dtype: float64

# %% [markdown]
# max duration of a call is 38 min. which seems reasonable

# %%
df_calls['good_id'] = df_calls.apply(lambda row : check_id(row['id'], row['user_id']), axis=1)

# %%
df_calls['good_id'].value_counts()
# Out:
# True    202607
# Name: good_id, dtype: int64

# %% [markdown]
# same value counts as total rows, which is good

# %%
df_calls = df_calls.drop(['good_id'], axis=1)

# %% [markdown]
# everything else looks good

# %% [markdown]
# ## generate data (for each user and each month)

# %% [markdown]
# ### number of calls

# %% [markdown]
# to generate number of calls for each month we first have to create a months table

# %%
df_calls['month'] = pd.DatetimeIndex(df_calls['call_date']).month

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Хорошо, добавили колонку с категорией месяца.</font>

# %%
df_calls.head()
# Out:
#        id  call_date  duration  user_id  month
# 0  1000_0 2018-07-25      0.00     1000      7
# 1  1000_1 2018-08-17      0.00     1000      8
# 2  1000_2 2018-06-11      2.85     1000      6
# 3  1000_3 2018-09-21     13.80     1000      9
# 4  1000_4 2018-12-15      5.18     1000     12

# %% [markdown]
# create a new table with 'id', 'user_id', 'month', 'calls_count' <br/>
# 'id' will be counted

# %%
df_calls_count = df_calls[['id', 'user_id', 'month']]

# %% [markdown]
# also this is a good time to include plan to this table

# %%
user_tariff = {}
def populate_user_tariff(row):
  user_id = row['user_id']
  tariff = row['tariff']
  user_tariff.update({user_id: tariff})

ok = df_users[['user_id', 'tariff']].apply(lambda row : populate_user_tariff(row), axis=1)

# %%
def find_tariff(row):
  user_id = row['user_id']
  tariff = user_tariff[user_id]
  return tariff

# %%
df_calls_count['tariff'] = df_calls_count.apply(lambda row : find_tariff(row), axis=1)
# Out:
# /var/folders/7_/tt886s4d5kzb54xrj7p8yyp00000gn/T/ipykernel_70741/180338334.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_calls_count['tariff'] = df_calls_count.apply(lambda row : find_tariff(row), axis=1)

# %% [markdown]
# also this is a good time to include city in this table

# %%
user_city = {}
def populate_user_city(row):
  user_id = row['user_id']
  city = row['city']
  user_city.update({user_id: city})

ok = df_users[['user_id', 'city']].apply(lambda row : populate_user_city(row), axis=1)

# %%
def find_city(row):
  user_id = row['user_id']
  city = user_city[user_id]
  return city

# %%
df_calls_count['city'] = df_calls_count.apply(lambda row : find_city(row), axis=1)

# %%
df_calls_count.head()
# Out:
#        id  user_id  month tariff       city
# 0  1000_0     1000      7  ultra  Краснодар
# 1  1000_1     1000      8  ultra  Краснодар
# 2  1000_2     1000      6  ultra  Краснодар
# 3  1000_3     1000      9  ultra  Краснодар
# 4  1000_4     1000     12  ultra  Краснодар

# %%
df_calls_count = df_calls_count.groupby(['user_id', 'month'], as_index=False).agg({'id':'count', 'tariff':pd.Series.mode, 'city':pd.Series.mode})

# %%
df_calls_count = df_calls_count.rename(columns={'id': 'calls'})

# %%
df_calls_count.head()
# Out:
#    user_id  month  calls tariff       city
# 0     1000      5     22  ultra  Краснодар
# 1     1000      6     43  ultra  Краснодар
# 2     1000      7     47  ultra  Краснодар
# 3     1000      8     52  ultra  Краснодар
# 4     1000      9     58  ultra  Краснодар

# %% [markdown]
# looks good!

# %% [markdown]
# ### minutes

# %% [markdown]
# create a new table with 'duration', 'user_id', 'month', 'calls_count' <br/>
# 'duration' will be counted

# %%
df_calls_minutes = df_calls[['duration', 'user_id', 'month']]

# %% [markdown]
# remember that call duration needs to round up to a whole minute

# %%
def round_up(row):
  duration = row['duration']
  return np.ceil(duration)

# %%
df_calls_minutes['duration'] = df_calls_minutes.apply(lambda row : round_up(row), axis=1)
# Out:
# /var/folders/7_/tt886s4d5kzb54xrj7p8yyp00000gn/T/ipykernel_70741/4117006191.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_calls_minutes['duration'] = df_calls_minutes.apply(lambda row : round_up(row), axis=1)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 math.ceil с помощью apply - не оптимальный способ. np.ceil подойдет лучше, т.к. может работать сразу со всем столбцом</font>

# %%
df_calls_minutes = df_calls_minutes.groupby(['user_id', 'month'], as_index=False).sum()

# %%
df_calls_minutes.head()
# Out:
#    user_id  month  duration
# 0     1000      5     159.0
# 1     1000      6     172.0
# 2     1000      7     340.0
# 3     1000      8     408.0
# 4     1000      9     466.0

# %% [markdown]
# looks good!

# %% [markdown]
# ### number of messages

# %% [markdown]
# to generate a number of messages each month we first have to create a month table

# %%
df_messages['month'] = pd.DatetimeIndex(df_messages['message_date']).month

# %%
df_messages.head()
# Out:
#        id message_date  user_id  month
# 0  1000_0   2018-06-27     1000      6
# 1  1000_1   2018-10-08     1000     10
# 2  1000_2   2018-08-04     1000      8
# 3  1000_3   2018-06-16     1000      6
# 4  1000_4   2018-12-05     1000     12

# %%
df_messages_count = df_messages[['id', 'user_id', 'month']]

# %%
df_messages_count = df_messages_count.groupby(['user_id', 'month'], as_index=False).count()

# %%
df_messages_count = df_messages_count.rename(columns={"id" : "messages"})

# %%
df_messages_count.head()
# Out:
#    user_id  month  messages
# 0     1000      5        22
# 1     1000      6        60
# 2     1000      7        75
# 3     1000      8        81
# 4     1000      9        57

# %% [markdown]
# looks good!

# %% [markdown]
# ### internet data used

# %% [markdown]
# to generate amount of used internet data each month we first have to create a month table

# %%
df_internet['month'] = pd.DatetimeIndex(df_internet['session_date']).month

# %%
df_internet_usage = df_internet[['mb_used', 'user_id', 'month']]

# %%
df_internet_usage = df_internet_usage.groupby(['user_id', 'month'], as_index=False).sum()

# %%
df_internet_usage.head()
# Out:
#    user_id  month   mb_used
# 0     1000      5   2253.49
# 1     1000      6  23233.77
# 2     1000      7  14003.64
# 3     1000      8  14055.93
# 4     1000      9  14568.91

# %% [markdown]
# remember that we will actually use the gb used, and usage rounds up

# %%
def round_to_gb(row):
  mb = row['mb_used']
  gb = mb / 1024
  gb = np.ceil(gb)
  return gb

# %%
df_internet_usage['gb'] = df_internet_usage.apply(lambda row : round_to_gb(row), axis=1)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера</b></font><br>
# <font color='DarkMagenta'>👉 И тут math.ceil с помощью apply - не оптимальный способ.</font>

# %%
df_internet_usage.head()
# Out:
#    user_id  month   mb_used    gb
# 0     1000      5   2253.49   3.0
# 1     1000      6  23233.77  23.0
# 2     1000      7  14003.64  14.0
# 3     1000      8  14055.93  14.0
# 4     1000      9  14568.91  15.0

# %% [markdown]
# looks good!

# %% [markdown]
# ### costs each month

# %% [markdown]
# combine data together, and apply a function

# %% [markdown]
# #### combine data

# %%
print('users in calls count', len(pd.unique(df_calls_count['user_id'])))
print('users in calls minutes', len(pd.unique(df_calls_minutes['user_id'])))
print('users in messages count', len(pd.unique(df_messages_count['user_id'])))
print('users in internet usage', len(pd.unique(df_internet_usage['user_id'])))
# Out:
# users in calls count 492
# users in calls minutes 492
# users in messages count 426
# users in internet usage 497

# %%
dfs = [df_calls_count, df_calls_minutes, df_messages_count, df_internet_usage]

# %%
df_costs = df_calls_count.copy()
df_costs = df_costs.merge(df_calls_minutes, how='outer', on=['user_id', 'month'])
df_costs = df_costs.merge(df_messages_count, how='outer', on=['user_id', 'month'])
df_costs = df_costs.merge(df_internet_usage, how='outer', on=['user_id', 'month'])

# %%
print('users in costs', len(pd.unique(df_costs['user_id'])))
# Out:
# users in costs 498

# %%
set_df_costs = set(pd.unique(df_costs['user_id']))
set_df_calls_count = set(pd.unique(df_calls_count['user_id']))
set_df_calls_minutes = set(pd.unique(df_calls_minutes['user_id']))
set_df_messages_count = set(pd.unique(df_messages_count['user_id']))
set_df_internet_usage = set(pd.unique(df_internet_usage['user_id']))
print('costs have calls count users', set_df_calls_count.issubset(set_df_costs))
print('costs have calls minutes users', set_df_calls_minutes.issubset(set_df_costs))
print('costs have messages count users', set_df_messages_count.issubset(set_df_costs))
print('costs have internet usage users', set_df_internet_usage.issubset(set_df_costs))
# Out:
# costs have calls count users True
# costs have calls minutes users True
# costs have messages count users True
# costs have internet usage users True

# %%
df_costs.head(15)
# Out:
#     user_id  month  calls tariff         city  duration  messages   mb_used  \
# 0      1000      5   22.0  ultra    Краснодар     159.0      22.0   2253.49
# 1      1000      6   43.0  ultra    Краснодар     172.0      60.0  23233.77
# 2      1000      7   47.0  ultra    Краснодар     340.0      75.0  14003.64
# 3      1000      8   52.0  ultra    Краснодар     408.0      81.0  14055.93
# 4      1000      9   58.0  ultra    Краснодар     466.0      57.0  14568.91
# 5      1000     10   57.0  ultra    Краснодар     350.0      73.0  14702.49
# 6      1000     11   43.0  ultra    Краснодар     338.0      58.0  14756.47
# 7      1000     12   46.0  ultra    Краснодар     333.0      70.0   9817.61
# 8      1001     11   59.0  smart       Москва     430.0       NaN  18429.34
# 9      1001     12   63.0  smart       Москва     414.0       NaN  14036.66
# 10     1002      6   15.0  smart  Стерлитамак     117.0       4.0  10856.82
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Надо проанализировать куда у нас пропало два пользователя после объединения таблиц, см. код ниже. Вот только не надо их сразу включать в сводную таблицу и считать на них выручку. Надо по ним принять правильное решение. </font>

# %%
# Комментарий ревьюера
len(df_costs.unstack())
# Out:
# 28926

# %% [markdown]
# looks good!

# %% [markdown]
# #### apply a calculating function

# %%
def smart_costs(duration, messages, gb):
  # min monthly cost 550
  # included: 500 min, 50 messages, 15 gb
  # extra prices: min = 3, message = 3, gb = 200
  total = 550
  if (duration > 500):
    total += (duration - 500) * 3
  if (messages > 50):
    total += (messages - 50) * 3
  if (gb > 15):
    total += (gb - 15) * 200
  return total

# %%
def ultra_costs(duration, messages, gb):
  # min monthly cost 1950
  # included; 3000 min, 1000 messages, 30 gb
  # extra prices: min = 1, message = 1, gb = 150
  total = 1950
  if (duration > 3000):
    total += (duration - 3000)
  if (messages > 1000):
    total += (messages - 1000)
  if (gb > 30):
    total += (gb - 30) * 150
  return total

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Рекомендуется не использовать в коде значения переменных, которые есть в датасете. Тогда при изменении тарифов мы можем использовать ранее написанный код при анализе просто загрузив новый датсет. 😲</font>

# %% [markdown]
# <div style='background:green'>
# funciton calculate_costs(row) берет 'row' и использует нужные колонки, это не правильно?
# </div>

# %%
def calculate_costs(row):
  tariff = row['tariff']
  duration = row['duration']
  messages = row['messages']
  gb = row['gb']
  if (tariff == 'smart'):
    return smart_costs(duration, messages, gb)
  return ultra_costs(duration, messages, gb)

# %%
df_costs['costs'] = df_costs.apply(lambda row : calculate_costs(row), axis=1)

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkGreen'>👌 Хорошо! Прописали расчет выручки.</font>

# %%
df_costs.head(20)
# Out:
#     user_id  month  calls tariff         city  duration  messages   mb_used  \
# 0      1000      5   22.0  ultra    Краснодар     159.0      22.0   2253.49
# 1      1000      6   43.0  ultra    Краснодар     172.0      60.0  23233.77
# 2      1000      7   47.0  ultra    Краснодар     340.0      75.0  14003.64
# 3      1000      8   52.0  ultra    Краснодар     408.0      81.0  14055.93
# 4      1000      9   58.0  ultra    Краснодар     466.0      57.0  14568.91
# 5      1000     10   57.0  ultra    Краснодар     350.0      73.0  14702.49
# 6      1000     11   43.0  ultra    Краснодар     338.0      58.0  14756.47
# 7      1000     12   46.0  ultra    Краснодар     333.0      70.0   9817.61
# 8      1001     11   59.0  smart       Москва     430.0       NaN  18429.34
# 9      1001     12   63.0  smart       Москва     414.0       NaN  14036.66
# 10     1002      6   15.0  smart  Стерлитамак     117.0       4.0  10856.82
# ...

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Но после объединения таблиц мы не проверили наличие пропусков и не приняли решения по ним. Надо это сделать.</font>

# %%
costs_users = set(pd.unique(df_costs['user_id']))
users = set(df_users['user_id'])
missing_users = users - costs_users
missing_users
# Out:
# {1128, 1371}

# %% [markdown]
# Видно что есть пользователи которые не попали в таблицу, но их не стоит добавлать. Так как если пользователь не пользуется услугами, то не стоит с него брать деньги.

# %% [markdown]
# Стоит заполнить пропуски в 'duration', 'messages', 'mb_used', 'gb'. На 0.

# %%
df_costs['duration'] = df_costs['duration'].fillna(0)
df_costs['messages'] = df_costs['messages'].fillna(0)
df_costs['mb_used'] = df_costs['mb_used'].fillna(0)
df_costs['gb'] = df_costs['gb'].fillna(0)

# %% [markdown]
# # Проанализируйте данные

# %% [markdown]
# ## make database for each tariff

# %% [markdown]
# create two tables for tariffs: "smart" and "ultra"

# %%
df_smart = df_costs[df_costs['tariff'] == 'smart']

# %%
df_smart.head()
# Out:
#     user_id  month  calls tariff         city  duration  messages   mb_used  \
# 8      1001     11   59.0  smart       Москва     430.0       0.0  18429.34
# 9      1001     12   63.0  smart       Москва     414.0       0.0  14036.66
# 10     1002      6   15.0  smart  Стерлитамак     117.0       4.0  10856.82
# 11     1002      7   26.0  smart  Стерлитамак     214.0      11.0  17580.10
# 12     1002      8   42.0  smart  Стерлитамак     289.0      13.0  20319.26
#
#       gb   costs
# 8   18.0  1150.0
# 9   14.0   550.0
# 10  11.0   550.0
# 11  18.0  1150.0
# 12  20.0  1550.0

# %%
df_ultra = df_costs[df_costs['tariff'] == 'ultra']

# %%
df_ultra.head()
# Out:
#    user_id  month  calls tariff       city  duration  messages   mb_used  \
# 0     1000      5   22.0  ultra  Краснодар     159.0      22.0   2253.49
# 1     1000      6   43.0  ultra  Краснодар     172.0      60.0  23233.77
# 2     1000      7   47.0  ultra  Краснодар     340.0      75.0  14003.64
# 3     1000      8   52.0  ultra  Краснодар     408.0      81.0  14055.93
# 4     1000      9   58.0  ultra  Краснодар     466.0      57.0  14568.91
#
#      gb   costs
# 0   3.0  1950.0
# 1  23.0  1950.0
# 2  14.0  1950.0
# 3  14.0  1950.0
# 4  15.0  1950.0

# %% [markdown]
# ## analyze mean, dispersion and standard deviation

# %% [markdown]
# ### duration

# %%
df_ultra['duration'].describe()
# Out:
# count     951.000000
# mean      545.451104
# std       306.925754
# min         0.000000
# 25%       310.000000
# 50%       528.000000
# 75%       756.500000
# max      1673.000000
# Name: duration, dtype: float64

# %%
df_smart['duration'].describe()
# Out:
# count    2223.000000
# mean      419.062978
# std       189.325618
# min         0.000000
# 25%       285.000000
# 50%       423.000000
# 75%       545.500000
# max      1435.000000
# Name: duration, dtype: float64

# %% [markdown]
# ### messages

# %%
df_ultra['messages'].describe()
# Out:
# count    951.000000
# mean      49.033649
# std       46.890656
# min        0.000000
# 25%        5.000000
# 50%       39.000000
# 75%       79.000000
# max      224.000000
# Name: messages, dtype: float64

# %%
df_smart['messages'].describe()
# Out:
# count    2223.000000
# mean       33.396311
# std        28.259437
# min         0.000000
# 25%        10.000000
# 50%        28.000000
# 75%        51.000000
# max       143.000000
# Name: messages, dtype: float64

# %% [markdown]
# ### data usage in gb

# %%
df_ultra['gb'].describe()
# Out:
# count    951.000000
# mean      19.487907
# std        9.890432
# min        0.000000
# 25%       12.000000
# 50%       19.000000
# 75%       27.000000
# max       49.000000
# Name: gb, dtype: float64

# %%
df_smart['gb'].describe()
# Out:
# count    2223.000000
# mean       16.329735
# std         5.752599
# min         0.000000
# 25%        13.000000
# 50%        17.000000
# 75%        20.000000
# max        38.000000
# Name: gb, dtype: float64

# %% [markdown]
# ### costs

# %%
df_ultra['costs'].describe()
# Out:
# count     951.000000
# mean     2070.977918
# std       379.423372
# min      1950.000000
# 25%      1950.000000
# 50%      1950.000000
# 75%      1950.000000
# max      4800.000000
# Name: costs, dtype: float64

# %%
df_smart['costs'].describe()
# Out:
# count    2223.000000
# mean     1290.891138
# std       819.119853
# min       550.000000
# 25%       550.000000
# 50%      1030.000000
# 75%      1750.000000
# max      6770.000000
# Name: costs, dtype: float64

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 А что у нас написано в задании: <b>Посчитайте среднее количество, дисперсию и стандартное отклонение. </b><br> А мы дисперсию не посчитали.</font>

# %% [markdown]
# ### dipsersion

# %%
df_ultra_duration_sample = random.sample(df_ultra['duration'].to_list(), 50)
df_smart_duration_sample = random.sample(df_smart['duration'].to_list(), 50)

print('dispersion in duration of calls for ultra tariff', np.var(df_ultra_duration_sample, ddof=1))
print('dispersion in duration of calls for smart tariff', np.var(df_smart_duration_sample, ddof=1))
# Out:
# dispersion in duration of calls for ultra tariff 85471.63265306123
# dispersion in duration of calls for smart tariff 35711.70448979592

# %%
df_ultra_messages_sample = random.sample(df_ultra['messages'].to_list(), 50)
df_smart_messages_sample = random.sample(df_smart['messages'].to_list(), 50)

print('dispersion in number of messages for ultra tariff', np.var(df_ultra_messages_sample, ddof=1))
print('dispersion in number of messages for smart tariff', np.var(df_smart_messages_sample, ddof=1))
# Out:
# dispersion in number of messages for ultra tariff 1927.5363265306125
# dispersion in number of messages for smart tariff 719.0404081632654

# %%
df_ultra_gb_sample = random.sample(df_ultra['gb'].to_list(), 50)
df_smart_gb_sample = random.sample(df_smart['gb'].to_list(), 50)

print('dispersion in number of gb used for ultra tariff', np.var(df_ultra_gb_sample, ddof=1))
print('dispersion in number of gb used for smart tariff', np.var(df_smart_gb_sample, ddof=1))
# Out:
# dispersion in number of gb used for ultra tariff 87.65265306122448
# dispersion in number of gb used for smart tariff 38.41183673469388

# %%
df_ultra_costs_sample = random.sample(df_ultra['costs'].to_list(), 50)
df_smart_costs_sample = random.sample(df_smart['costs'].to_list(), 50)

print('dispersion for costs for ultra tariff', np.var(df_ultra_costs_sample, ddof=1))
print('dispersion for costs for smart tariff', np.var(df_smart_costs_sample, ddof=1))
# Out:
# dispersion for costs for ultra tariff 120342.85714285714
# dispersion for costs for smart tariff 716294.0200000001

# %% [markdown]
# ## build histograms and describe the distribution

# %% [markdown]
# ### duration

# %%
print('red is ultra, blue is smart')
df_ultra['duration'].hist(bins=20, fc=(0, 0, 1, 0.7))
df_smart['duration'].hist(bins=20, fc=(1, 0, 0, 0.7))
plt.show()
# Out:
# red is ultra, blue is smart

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 При проведении сравнительного анализа лучше на графики выводить данные обоих тарифов в одной координатной сетке с указанием меток тарифов. Сделаем?</font>

# %% [markdown]
# We can see that dispersion on the smart plan is smaller, and we can also see that around 500 minute mark the count drops significantly, which is likely caused by the fact that 500 minutes are included, and everything after requires aditional funds. Both histograms follow the normal distribution.

# %% [markdown]
# ### messages

# %%
print('red is ultra, blue is smart')
df_ultra['messages'].hist(bins=20, fc=(0, 0, 1, 0.7))
df_smart['messages'].hist(bins=20, fc=(1, 0, 0, 0.7))
plt.show()
# Out:
# red is ultra, blue is smart

# %% [markdown]
# Both graphs seem to follow exponential distribution with a very low rate.

# %% [markdown]
# ### data usage (gb)

# %%
print('red is ultra, blue is smart')
df_ultra['gb'].hist(bins=20, fc=(0, 0, 1, 0.7))
df_smart['gb'].hist(bins=20, fc=(1, 0, 0, 0.7))
plt.show()
# Out:
# red is ultra, blue is smart

# %% [markdown]
# Both histograms follow the normal distribution.

# %% [markdown]
# ### prices

# %%
print('red is ultra, blue is smart')
df_ultra['costs'].hist(bins=20, fc=(0, 0, 1, 0.7))
df_smart['costs'].hist(bins=20, fc=(1, 0, 0, 0.7))
plt.show()
# Out:
# red is ultra, blue is smart

# %% [markdown]
# Both historgrams follow the exponential distribution with a very hight rate.

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Как инструкция на выполнение проекта, так и технические задания на проведение исследования не всегда содержат всю информацию, что необходимо сделать. Но указывается задача исследования, у нас это: "коммерческий департамент хочет понять, какой тариф приносит больше денег". Но мы ограничиваемся в анализе только количеством сообщений, длительностью звонков и интернет-трафиком. При этом у нас уже посчитано сколько пользователи платят за эти услуги, но сам анализ выручки в разрезе тарифа мы не делаем. Тогда, как мы получим ответ на вопрос какой тариф выгоднее?</font><br>
# <font color='Red'>🛠 Надо, кроме гистограмм посчитать среднее количество, дисперсию и стандартное отклонение по выручке в разрезе тарифов. Хорошо?</font>

# %% [markdown]
# # Проверьте гипотезы

# %% [markdown]
# ## profits are different for each tariff

# %% [markdown]
# средняя выручка пользователей тарифов «Ультра» и «Смарт» различаются

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Мы не сформулировали гипотезы. Здесь и ниже.</font>

# %%
print(len(df_ultra['costs']))
print(len(df_smart['costs']))
# Out:
# 951
# 2223

# %%
alpha = 0.05
ultra_cost_sample = df_ultra['costs']
smart_cost_sample = df_smart['costs']
costs_compare = st.ttest_ind(ultra_cost_sample, smart_cost_sample)

print('costs compare p-value:', costs_compare.pvalue)

if (costs_compare.pvalue < alpha):
  print('ultra costs and smart costs are different')
else:
  print('ultra costs and smart costs are comparable')
# Out:
# costs compare p-value: 2.1830308249112928e-155
# ultra costs and smart costs are different

# %%
print('mean costs for ultra plan', df_ultra['costs'].mean())
print('mean costs for smart plan', df_smart['costs'].mean())
# Out:
# mean costs for ultra plan 2070.9779179810726
# mean costs for smart plan 1290.8911381016644

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Равенство размеров выборок для проверки гипотез не нужно, более того - почти всегда все работают с не равными по размеру выборками. А нас интересуют средние значения рейтингов, которые мы искажаем путем урезания одной выборки.</font>

# %% [markdown]
# <div style='background:green'>
# я сделал веборку для оптимизации и думал что 30 проб достаточно
# </div>

# %% [markdown]
# ## profits from "Moscow" and other regions are different

# %% [markdown]
# средняя выручка пользователей из Москвы отличается от выручки пользователей из других регионов

# %%
df_costs.info()
df_costs.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 0 to 3213
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   3214 non-null   int64
#  1   month     3214 non-null   int64
#  2   calls     3174 non-null   float64
#  3   tariff    3174 non-null   object
#  4   city      3174 non-null   object
#  5   duration  3214 non-null   float64
#  6   messages  3214 non-null   float64
#  7   mb_used   3214 non-null   float64
#  8   gb        3214 non-null   float64
#  9   costs     3214 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 405.2+ KB
#    user_id  month  calls tariff       city  duration  messages   mb_used  \
# 0     1000      5   22.0  ultra  Краснодар     159.0      22.0   2253.49
# 1     1000      6   43.0  ultra  Краснодар     172.0      60.0  23233.77
# 2     1000      7   47.0  ultra  Краснодар     340.0      75.0  14003.64
# ...

# %%
df_moscow = df_costs[df_costs['city'] == 'Москва']
df_other_regions = df_costs[df_costs['city'] != 'Москва']

# %%
print(len(df_moscow['costs']))
print(len(df_other_regions['costs']))
# Out:
# 610
# 2604

# %%
df_moscow_sample = df_moscow['costs']
df_other_regions_sample = df_other_regions['costs']
alpha = 0.05
regions_compare = st.ttest_ind(df_moscow_sample, df_other_regions_sample)

print('costs regions compare p-value:', regions_compare.pvalue)

if (regions_compare.pvalue < alpha):
  print('Moscow costs and smart costs are different')
else:
  print('Moscow costs and smart costs are comparable')
# Out:
# costs regions compare p-value: 0.6034325999259914
# Moscow costs and smart costs are comparable

# %%
print('mean costs in moscow', df_moscow['costs'].mean())
print('mean costs in other regions', df_other_regions['costs'].mean())
# Out:
# mean costs in moscow 1546.0524590163934
# mean costs in other regions 1527.4036098310291

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 И тут у нас аналогичная ошибка. </font>

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='DarkMagenta'>👉 Было бы правильным показать дополнительно средние выручки и по тарифам, и по регионам, как иллюстрации не противоречивости нашей проверки гипотез.</font>

# %% [markdown]
# # Напишите общий вывод

# %% [markdown]
# прибыль оказалась разной для тарифов 'ultra' & 'smart'

# %% [markdown]
# прибыль оказалось одинаковой для Москвы и других регионов?

# %% [markdown]
# <font color='DarkBlue'><b>Комментарий ревьюера 2</b></font><br>
# <font color='Red'>🛠 Как мы в отсутсвующем описании проекта не выделили цель исследования, так и в общих выводах это не отразили.</font><br>
# <font color='DarkMagenta'>👉 И очень пригодился бы график динамики выручки по месяцам в разрезе тарифов. Есть ли там тренды, выручка по какому-то тарифу растет или падает? Сделаем?</font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера</b></font><br>
# <font color='DarkGreen'>👌 Владислав!<br></font>
# <font color='Red'>🛠 Увы, должен прервать ревью из-за ошибки в коде. Настоятельно рекомендую перед отправкой проекта на ревью проверять в JupyterHub исполнение кода тетрадки. 🙄 <br>
# Необходимо исправить ошибки, в том числе уже обнаруженные:<br>
# Сделать описание проекта с целью исследования.<br>
# Жду исправленный проект. Если будут трудности, можно обратиться к куратору. </font>

# %% [markdown]
# <font color='DarkBlue'><b>Заключительный комментарий ревьюера 2</b></font><br><br>
# <font color='DarkGreen'>👌 Владислав!, проект очень хорошо и детально проработан. И дальше так держать!<br></font>
# <font color='Red'>🛠 А что бы еще лучше сделать проект нам надо:</font><br>
# <font color='Red'>🛠 Сделать описание проекта с целью исследования. Проанализировать пропажу пользователей после объединения таблиц. Надо проверить на пропуски итоговую таблицу после объединения и принять решение по ним. Посчитать дисперсию по тарифам. Посчитать статистику по выручке в разрезе тарифов. Необходимо переделать раздел проверки гипотез. В итоговом выводе должна найти свое отражение цель исследования. <br></font>
# <font color='DarkMagenta'>👉 При исправлении ошибок и недочетов мы приобретем дополнительный опыт и навыки!</font><br>
# <font color='DarkGreen'>👌 Жду окончательный вариант! Удачи. </font>
